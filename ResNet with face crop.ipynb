# %%
import numpy as np
import pandas as pd
import sklearn as sk
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import layers, models

from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split

# %%
train_file = open("./Full-labels-2.txt")
lines = train_file.readlines()
train_file.close()

filenames = []
labels = []

for line in lines:
    filenames.append('Celeb-DF-Image-Face-Crop/'+line[2:].rstrip('\n'))    
for l in lines:
    labels.append(l[:1])

labels = [int(i) for i in labels]

train_filenames, val_filenames, train_labels, val_labels = train_test_split(
    filenames, labels, train_size=0.85, random_state=420)

num_train = len(train_filenames)
num_val = len(val_filenames)

# %%
train_data = tf.data.Dataset.from_tensor_slices((tf.constant(train_filenames), tf.constant(train_labels)))

val_data = tf.data.Dataset.from_tensor_slices((tf.constant(val_filenames), tf.constant(val_labels)))

# %%
#  function that can load the images from file and perform any necessary preprocessing.

IMAGE_SIZE = 128
BATCH_SIZE = 32

def _parse_fn(img, label):
    img_string = tf.io.read_file(img)
    img_decoded = tf.image.decode_jpeg(img_string)
    img_normalized = (tf.cast(img_decoded, tf.float32)/127.5) - 1
    img_resized = tf.image.resize(img_normalized, (IMAGE_SIZE, IMAGE_SIZE))
    #img_preprocess = tf.keras.applications.resnet_v2.preprocess_input(img_resized)
    return img_resized, label

train_data = (train_data.map(_parse_fn).shuffle(buffer_size=1000).batch(BATCH_SIZE))
val_data = (val_data.map(_parse_fn).shuffle(buffer_size=1000).batch(BATCH_SIZE))

# %%
IMG_SHAPE = (IMAGE_SIZE, IMAGE_SIZE, 3)
base_model = tf.keras.applications.ResNet50V2(
    include_top=False, weights="imagenet",
    input_shape=IMG_SHAPE, pooling="max", classes=2,
    classifier_activation="relu"
)

# %%
base_model.trainable = False

# %%
prediction_layer = tf.keras.layers.Dense(1, activation='sigmoid')

model = tf.keras.Sequential([
    base_model,
    prediction_layer
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23564800
# _________________________________________________________________
# dense (Dense)                (None, 1)                 2049
# =================================================================
# Total params: 23,566,849
# Trainable params: 2,049
# Non-trainable params: 23,564,800
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.0001),
             loss='binary_crossentropy',
             metrics=['accuracy'])

# %%
epochs = 40
steps_per_epoch = 50
val_steps = 20


history = model.fit(train_data.repeat(),
                      epochs = epochs,
                      steps_per_epoch = steps_per_epoch,
                      validation_data = val_data.repeat(), 
                      validation_steps = val_steps)
# Out:
# Epoch 1/40
# 50/50 [==============================] - 28s 568ms/step - loss: 0.7716 - accuracy: 0.7788 - val_loss: 0.7097 - val_accuracy: 0.8141
# Epoch 2/40
# 50/50 [==============================] - 29s 588ms/step - loss: 0.6773 - accuracy: 0.8094 - val_loss: 0.6354 - val_accuracy: 0.8156
# Epoch 3/40
# 50/50 [==============================] - 28s 552ms/step - loss: 0.6100 - accuracy: 0.8231 - val_loss: 0.5451 - val_accuracy: 0.8391
# Epoch 4/40
# 50/50 [==============================] - 29s 583ms/step - loss: 0.5765 - accuracy: 0.8024 - val_loss: 0.5887 - val_accuracy: 0.8344
# Epoch 5/40
# 50/50 [==============================] - 28s 568ms/step - loss: 0.5842 - accuracy: 0.8119 - val_loss: 0.5669 - val_accuracy: 0.8391
# Epoch 6/40
# 50/50 [==============================] - 28s 551ms/step - loss: 0.5131 - accuracy: 0.8350 - val_loss: 0.4889 - val_accuracy: 0.8562
# Epoch 7/40
# 50/50 [==============================] - 29s 579ms/step - loss: 0.5285 - accuracy: 0.8227 - val_loss: 0.5029 - val_accuracy: 0.8562
# Epoch 8/40
# 50/50 [==============================] - 30s 603ms/step - loss: 0.4849 - accuracy: 0.8381 - val_loss: 0.5204 - val_accuracy: 0.8562
# Epoch 9/40
# 50/50 [==============================] - 28s 562ms/step - loss: 0.4685 - accuracy: 0.8500 - val_loss: 0.4893 - val_accuracy: 0.8281
# Epoch 10/40
# 50/50 [==============================] - 29s 578ms/step - loss: 0.4944 - accuracy: 0.8297 - val_loss: 0.4849 - val_accuracy: 0.8469
# Epoch 11/40
# 50/50 [==============================] - 29s 573ms/step - loss: 0.4701 - accuracy: 0.8475 - val_loss: 0.5012 - val_accuracy: 0.8359
# Epoch 12/40
# 50/50 [==============================] - 28s 568ms/step - loss: 0.4025 - accuracy: 0.8606 - val_loss: 0.4661 - val_accuracy: 0.8562
# Epoch 13/40
# 50/50 [==============================] - 30s 590ms/step - loss: 0.4773 - accuracy: 0.8278 - val_loss: 0.4190 - val_accuracy: 0.8641
# Epoch 14/40
# 50/50 [==============================] - 29s 573ms/step - loss: 0.4292 - accuracy: 0.8531 - val_loss: 0.4485 - val_accuracy: 0.8547
# Epoch 15/40
# 50/50 [==============================] - 29s 575ms/step - loss: 0.4182 - accuracy: 0.8556 - val_loss: 0.4489 - val_accuracy: 0.8625
# Epoch 16/40
# 50/50 [==============================] - 29s 585ms/step - loss: 0.4235 - accuracy: 0.8494 - val_loss: 0.4496 - val_accuracy: 0.8750
# Epoch 17/40
# 50/50 [==============================] - 29s 582ms/step - loss: 0.4100 - accuracy: 0.8525 - val_loss: 0.4366 - val_accuracy: 0.8687
# Epoch 18/40
# 50/50 [==============================] - 28s 566ms/step - loss: 0.3862 - accuracy: 0.8725 - val_loss: 0.4416 - val_accuracy: 0.8594
# Epoch 19/40
# 50/50 [==============================] - 28s 569ms/step - loss: 0.4114 - accuracy: 0.8482 - val_loss: 0.4513 - val_accuracy: 0.8578
# Epoch 20/40
# 50/50 [==============================] - 29s 583ms/step - loss: 0.3899 - accuracy: 0.8644 - val_loss: 0.4428 - val_accuracy: 0.8594
# Epoch 21/40
# 50/50 [==============================] - 29s 570ms/step - loss: 0.4122 - accuracy: 0.8531 - val_loss: 0.4261 - val_accuracy: 0.8719
# Epoch 22/40
# 50/50 [==============================] - 29s 574ms/step - loss: 0.3585 - accuracy: 0.8818 - val_loss: 0.4057 - val_accuracy: 0.8797
# Epoch 23/40
# 50/50 [==============================] - 29s 577ms/step - loss: 0.3938 - accuracy: 0.8600 - val_loss: 0.4148 - val_accuracy: 0.8719
# Epoch 24/40
# 50/50 [==============================] - 29s 575ms/step - loss: 0.3683 - accuracy: 0.8731 - val_loss: 0.4477 - val_accuracy: 0.8719
# Epoch 25/40
# 50/50 [==============================] - 29s 577ms/step - loss: 0.3740 - accuracy: 0.8691 - val_loss: 0.4579 - val_accuracy: 0.8625
# Epoch 26/40
# 50/50 [==============================] - 29s 572ms/step - loss: 0.3930 - accuracy: 0.8650 - val_loss: 0.4452 - val_accuracy: 0.8516
# Epoch 27/40
# 50/50 [==============================] - 29s 572ms/step - loss: 0.3612 - accuracy: 0.8769 - val_loss: 0.4234 - val_accuracy: 0.8734
# Epoch 28/40
# 50/50 [==============================] - 28s 567ms/step - loss: 0.3566 - accuracy: 0.8774 - val_loss: 0.4176 - val_accuracy: 0.8422
# Epoch 29/40
# 50/50 [==============================] - 29s 574ms/step - loss: 0.3764 - accuracy: 0.8687 - val_loss: 0.4082 - val_accuracy: 0.8766
# Epoch 30/40
# 50/50 [==============================] - 29s 571ms/step - loss: 0.3179 - accuracy: 0.8888 - val_loss: 0.3907 - val_accuracy: 0.8797
# Epoch 31/40
# 50/50 [==============================] - 27s 545ms/step - loss: 0.3594 - accuracy: 0.8806 - val_loss: 0.3947 - val_accuracy: 0.8844
# Epoch 32/40
# 50/50 [==============================] - 28s 567ms/step - loss: 0.3549 - accuracy: 0.8769 - val_loss: 0.3892 - val_accuracy: 0.8813
# Epoch 33/40
# 50/50 [==============================] - 29s 570ms/step - loss: 0.3389 - accuracy: 0.8813 - val_loss: 0.4209 - val_accuracy: 0.8766
# Epoch 34/40
# 50/50 [==============================] - 28s 566ms/step - loss: 0.3540 - accuracy: 0.8800 - val_loss: 0.4269 - val_accuracy: 0.8656
# Epoch 35/40
# 50/50 [==============================] - 30s 596ms/step - loss: 0.3486 - accuracy: 0.8825 - val_loss: 0.3945 - val_accuracy: 0.8828
# Epoch 36/40
# 50/50 [==============================] - 28s 567ms/step - loss: 0.3375 - accuracy: 0.8838 - val_loss: 0.4303 - val_accuracy: 0.8703
# Epoch 37/40
# 50/50 [==============================] - 28s 558ms/step - loss: 0.3143 - accuracy: 0.8931 - val_loss: 0.4035 - val_accuracy: 0.8734
# Epoch 38/40
# 50/50 [==============================] - 29s 579ms/step - loss: 0.3609 - accuracy: 0.8767 - val_loss: 0.3986 - val_accuracy: 0.8672
# Epoch 39/40
# 50/50 [==============================] - 29s 574ms/step - loss: 0.3307 - accuracy: 0.8844 - val_loss: 0.4000 - val_accuracy: 0.8766
# Epoch 40/40
# 50/50 [==============================] - 28s 559ms/step - loss: 0.3160 - accuracy: 0.8819 - val_loss: 0.3731 - val_accuracy: 0.8734

# %%
model.save_weights('./ResNet-Weights/weights_epoch_30.h5')

# %%
history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
pred = model.predict(val_data, verbose=1)
# Out:
# 28/28 [==============================] - 10s 357ms/step

# %%
model.evaluate(val_data)
# Out:
# 28/28 [==============================] - 10s 368ms/step - loss: 0.3937 - accuracy: 0.8772
# [0.39368417859077454, 0.877152681350708]

# %%
from sklearn.metrics import roc_auc_score
y_true = np.array(val_labels)
y_scores = pred
roc_auc_score(y_true, y_scores)
# Out:
# 0.5330440739894954

# %%
tf.math.confusion_matrix(y_true, y_scores)

classes=["Fake", "Real"]

con_mat = tf.math.confusion_matrix(labels=y_true.ravel(), predictions=y_scores.ravel(), num_classes=2).numpy()
con_mat_norm = np.around(con_mat.astype('float') / con_mat.sum(axis=1)[:, np.newaxis], decimals=2)
print(con_mat)
print("")
 
con_mat_df = pd.DataFrame(con_mat_norm,
                     index = classes, 
                     columns = classes)


sns.heatmap(con_mat_df, annot=True,cmap=plt.cm.Blues)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# [[755   0]
#  [116   0]]

# %%
fpr = dict()
tpr = dict()
roc_auc = dict()
fpr, tpr, thresholds = metrics.roc_curve(y_true, y_scores, pos_label=None)
roc_auc = auc(fpr, tpr)

plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()

# %%
report = metrics.classification_report(y_true,np.round(y_scores),labels=[1,0])
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.18      0.07      0.10       116
#            0       0.87      0.95      0.91       755
#
#     accuracy                           0.83       871
#    macro avg       0.52      0.51      0.50       871
# weighted avg       0.78      0.83      0.80       871
